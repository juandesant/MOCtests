# %%
import sys

# %%
sys.version
# Out:
# '3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:07:29) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
# %matplotlib inline

# %%
from mocpy import MOC

# %%
m2 = MOC.from_fits('data/P-SDSS9-r.MOC.fits')

# %%
m2.plot(title='SDSS9 band r coverage')

# %%
m2.sky_fraction
# Out:
# 0.3624379634857178

# %%
m1 = MOC.from_fits('data/II_311_wise-512.MOC.fits')

# %%
m1.plot()

# %%
m1.complement().sky_fraction
# Out:
# 0.0006806055704752604

# %%
m1_2 = m1.complement().intersection(m2)

# %%
m1.difference(m2).sky_fraction
# Out:
# 0.6368821461995443

# %%
m1.difference(m2).plot()

# %%
m3 = MOC.from_fits("/Users/j.santander-vela/Downloads/gaia2_sdss9_MOC.fits")

# %%
m1 = MOC.from_fits("/Users/j.santander-vela/Downloads/P-SDSS9-r.MOC.fits")

# %%
m1.max_order
# Out:
# 10

# %%
_.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e3c42177a5d5> in <module>
# ----> 1 _.plot()
#
# AttributeError: 'int' object has no attribute 'plot'

# %%
m3.degrade_to_order(4)
# Out:
# [[                  0   12384898975268864]
#  [  13510798882111488   15762598695796736]
#  [  16888498602639360   30399297484750848]
#  [  36028797018963968   40532396646334464]
#  [  41658296553177088   56294995342131200]
#  [  57420895248973824   59672695062659072]
#  [  60798594969501696   61924494876344320]
#  [  63050394783186944   78812993478983680]
#  [  81064793292668928   83316593106354176]
#  [  84442493013196800   86694292826882048]
#  [  87820192733724672   90071992547409920]
#  [  95701492081623040   99079191802150912]
#  [ 103582791429521408  105834591243206656]
#  [ 108086391056891904  113715890591105024]
#  [ 114841790497947648  115967690404790272]
#  [ 117093590311632896  126100789566373888]
#  [ 137359788634800128  163255486492180480]
#  [ 164381386399023104  165507286305865728]
#  [ 167759086119550976  171136785840078848]
#  [ 173388585653764096  179018085187977216]
#  [ 180143985094819840  191402984163246080]
#  [ 193654783976931328  194780683883773952]
# ...

# %%
m3.plot()
